# %% [markdown]
# # ANALYSIS OF STUDENTS PERFORMANCE

# %% [markdown]
# ## What are the factors that influence students performance ?

# %% [markdown]
# The academic performance of students is influenced by several and various factors. This analysis is held to attentively look at those factors and in what extent they influence the students academic performance. The Python libraries that will be used are Numpy, Matplotlib, Seaborn and Pandas.

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## The data

# %%
data = pd.read_csv("./StudentsPerformance.csv")
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# The dataset has no null value!

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FF1C456988>,
# ...
#       dtype=object)

# %% [markdown]
# With this result, it can be inferred that there are only three numerical columns.

# %%
data.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %% [markdown]
# The unique data have been counted. It can be inferred that there are only :
#
#     - two genders (male and female)
#
#     - 5 rates or ethnicities
#
#     - 6 parental level of education
#
#     - 2 types of lunches

# %% [markdown]
# ### Any Outliers ?

# %%
data.boxplot()

# %% [markdown]
# ## The number of male

# %%
data[data['gender']=="male"]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %%
data[data['gender']=="male"].count()
# Out:
# gender                         482
# race/ethnicity                 482
# parental level of education    482
# lunch                          482
# test preparation course        482
# math score                     482
# reading score                  482
# writing score                  482
# dtype: int64

# %% [markdown]
# Out of 1000 records, 482 are male. Less than 50% of the records concern the male students.

# %%
data[data['gender']=="female"]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data[data['gender']=="female"].count()
# Out:
# gender                         518
# race/ethnicity                 518
# parental level of education    518
# lunch                          518
# test preparation course        518
# math score                     518
# reading score                  518
# writing score                  518
# dtype: int64

# %% [markdown]
# Girls are more represented than boys in this school. In many schools, this is rarely the case.

# %% [markdown]
# ## Which data will not be very helpful for the analysis ?

# %% [markdown]
# In this dataset, there is a column named "race/ethnicity" and which is clearly not going to help us have more insights. So, this column will be deleted.

# %%
new_data = data.drop(["race/ethnicity"], axis=1)
new_data.head()
# Out:
#    gender parental level of education         lunch test preparation course  \
# 0  female           bachelor's degree      standard                    none
# 1  female                some college      standard               completed
# 2  female             master's degree      standard                    none
# 3    male          associate's degree  free/reduced                    none
# 4    male                some college      standard                    none
#
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# ## Parental level of education by gender

# %%
female_data = data[0:].query('gender=="female"')
female_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
female_data["parental level of education"].hist()

# %%
male_data = data[0:].query('gender=="male"')
male_data
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %%
male_data["parental level of education"].hist()

# %%
new_data["lunch"].hist()

# %% [markdown]
# 65% of the students have the standard meal while only 35%, a little more than the half of the previous value, have free or reduced meal.
# This means that the majority of students can afford a standard meal. Let's check whether this affects or not the students performance.

# %% [markdown]
# ## Relationships Analysis

# %%
correlation = new_data.corr()
correlation
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %% [markdown]
# ## Correlation between the three subjects

# %%
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True)

# %%
sns.pairplot(new_data)

# %% [markdown]
# ## Math and Reading Scores

# %%
sns.relplot(x="math score", y="reading score", data = new_data)

# %% [markdown]
# ## Writing and Reading Scores

# %%
sns.relplot(x="writing score", y="reading score", data = new_data)

# %% [markdown]
# ## Math and Writing Scores

# %%
sns.relplot(x="math score", y="writing score", data = new_data)

# %% [markdown]
# The 3 subjects scores are strongly linked, especially the relation between the writing and reading scores.

# %% [markdown]
# ## Math & Reading scores correlation grouped by Parental level of education

# %%
sns.relplot(x="math score", y="reading score", hue="parental level of education", data = new_data)

# %% [markdown]
# ## Math & Reading scores correlation grouped by the lunch type

# %%
sns.relplot(x="math score", y="reading score", hue="lunch", data = new_data)

# %% [markdown]
# ## Math & Reading scores correlation grouped by Test Preparation Course

# %%
sns.relplot(x="math score", y="reading score", hue="test preparation course", data = new_data)

# %% [markdown]
# ## Distributions

# %%
sns.distplot(new_data["math score"], bins=20)

# %%
sns.distplot(new_data["reading score"], bins=20)

# %%
sns.distplot(new_data["writing score"], bins=20)

# %%
sns.relplot(x="math score", y="gender", data = new_data)

# %%
sns.relplot(x="reading score", y="gender", data = new_data)

# %%
sns.relplot(x="writing score", y="gender", data = new_data)
