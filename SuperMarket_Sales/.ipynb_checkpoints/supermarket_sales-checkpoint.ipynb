# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#import qgrid as qg
#grid_data = qg.show_grid(mydata)
#grid_data

# %%
mydata = pd.read_csv("./supermarket_sales.csv")

# %%
mydata.shape
# Out:
# (1000, 17)

# %%
mydata.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
mydata.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
mydata.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
mydata.columns.tolist()
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Unit price',
#  'Quantity',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'Payment',
#  'cogs',
#  'gross margin percentage',
#  'gross income',
#  'Rating']

# %%
mydata.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
mydata.nunique()
# Out:
# Invoice ID                 1000
# Branch                        3
# City                          3
# Customer type                 2
# Gender                        2
# Product line                  6
# Unit price                  943
# Quantity                     10
# Tax 5%                      990
# Total                       990
# Date                         89
# Time                        506
# Payment                       3
# cogs                        990
# gross margin percentage       1
# gross income                990
# Rating                       61
# dtype: int64

# %%
mydata.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
mydata["Date"].tail(10)
# Out:
# 990    3/22/2019
# 991    1/24/2019
# 992    3/10/2019
# 993    2/22/2019
# 994    2/18/2019
# 995    1/29/2019
# 996     3/2/2019
# 997     2/9/2019
# 998    2/22/2019
# 999    2/18/2019
# Name: Date, dtype: object

# %%
mydata.Date = pd.to_datetime(mydata.Date)
mydata.Date.tail()
# Out:
# 995   2019-01-29
# 996   2019-03-02
# 997   2019-02-09
# 998   2019-02-22
# 999   2019-02-18
# Name: Date, dtype: datetime64[ns]

# %%
mydata["Branch"].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
mydata["Gender"].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
mydata["Invoice ID"].head(10)
# Out:
# 0    750-67-8428
# 1    226-31-3081
# 2    631-41-3108
# 3    123-19-1176
# 4    373-73-7910
# 5    699-14-3026
# 6    355-53-5943
# 7    315-22-5665
# 8    665-32-9167
# 9    692-92-5582
# Name: Invoice ID, dtype: object

# %%
mydata.Branch.nunique()
# Out:
# 3

# %%
mydata.Branch.unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
mydata.Branch.mode()
# Out:
# 0    A
# dtype: object

# %%
mydata["City"].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
mydata["Product line"].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
mydata["Product line"].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
mydata["Product line"].mode()
# Out:
# 0    Fashion accessories
# dtype: object

# %%
new_data = mydata.drop(columns="Invoice ID")
new_data
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %%
plt.figure(figsize=(14,6))
mydata.boxplot()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,5))
sns.set(rc={"axes.grid":True, "axes.facecolor":"brown"})
sns.barplot(x="Branch", y="Total", data=new_data)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.set(rc={"axes.grid":True, "axes.facecolor":"#01E1"})
sns.barplot(x="Branch", y="Total", hue="Gender", data=new_data)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.set(rc={"axes.grid":True, "axes.facecolor":"pink"})
sns.barplot(x="City", y="Total", data=new_data)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.set(rc={"axes.grid":True, "axes.facecolor":"#1477"})
sns.barplot(x="City", y="Total", hue="Gender", data=new_data)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Total'>

# %%
plt.figure(figsize=(15,7))
sns.set(rc={"axes.grid":True, "axes.facecolor":"None"})
sns.barplot(x="Product line", y="Total", data=new_data)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,7))
sns.set(rc={"axes.grid":True, "axes.facecolor":"orange"})
sns.barplot(x="Product line", y="Total", hue="Gender", data=new_data)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(14,5))
sns.set(rc={"axes.grid":True, "axes.facecolor":"None"})
sns.barplot(x="Product line", y="Total", hue="Customer type", data=new_data)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,7))
sns.set(rc={"axes.grid":True, "axes.facecolor":"#2375"})
sns.barplot(x="Product line", y="Total", hue="Payment", data=new_data)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,7))
sns.set(rc={"axes.grid":False, "axes.facecolor":"#ee77"})
sns.barplot(x="City", y="Total", hue="Payment", data=new_data)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Total'>

# %%
plt.figure(figsize=(25,7))
sns.set(rc={"axes.grid":True, "axes.facecolor":"#2775"})
sns.lineplot(x="Date", y="Total", data=new_data, linewidth=2)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Total'>
